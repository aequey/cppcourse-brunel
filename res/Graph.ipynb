# %%
import numpy as np
import pylab as pl

data = np.genfromtxt('data.dat')

# %%
select= np.array ([d for d in data if d[1] < 50 and d[0]*0.1>900])
data1= select.transpose()

pl.scatter(data1[0]*0.1,data1[1],alpha=0.8, edgecolors='none');
pl.show();

# %%
n, bins, patches = pl.hist(0.1*data1[0], 50, normed=0, alpha=0.75)
pl.show();
